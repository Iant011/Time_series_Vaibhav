# %% [markdown]
# # 1.Simple Moving Average
# # 2. Cumulutive Moving Average
# # 3.Exponential moving average
# # 4.Moving Average ACF (Auto Corr Plot) -- (MA)
# # 5.Auto Regressive Model PACF(Partical Auto Corr Plot)-- (AR)
# # AR + MA = ARMA
# # ARIMA, ARIMAX, SARIMAX

# %%
import pandas_datareader as pdr
import pandas as pd
import datetime
from datetime import datetime
from pandas_datareader import data as pdr
import yfinance as yfin

# %%
yfin.pdr_override()

df_Tsl = pdr.get_data_yahoo('TSLA', start='2019-10-24', end='2023-8-21')

df_Tsl
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-10-24   19.891333   20.328667   19.280001   19.978666   19.978666
# 2019-10-25   19.848000   22.000000   19.740667   21.875334   21.875334
# 2019-10-28   21.836000   22.722668   21.506666   21.847334   21.847334
# 2019-10-29   21.332666   21.620001   20.983334   21.081333   21.081333
# 2019-10-30   20.866667   21.252666   20.664667   21.000668   21.000668
# ...                ...         ...         ...         ...         ...
# 2023-08-14  235.699997  240.660004  233.750000  239.759995  239.759995
# 2023-08-15  238.729996  240.500000  232.610001  232.960007  232.960007
# 2023-08-16  228.020004  233.970001  225.380005  225.600006  225.600006
# 2023-08-17  226.059998  226.740005  218.830002  219.220001  219.220001
# 2023-08-18  214.119995  217.580002  212.360001  215.490005  215.490005
#
#                Volume
# Date
# ...

# %%
# 1.Simple Moving Average

# %%
df_Tsl.plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Tsl['Open:10Days']=df_Tsl['Open'].rolling(window=10).mean()

# %%
df_Tsl[['Open','Open:10Days']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Tsl['Open:50Days']=df_Tsl['Open'].rolling(window=50).mean()
df_Tsl['Open:200Days']=df_Tsl['Open'].rolling(window=200).mean()

# %%
df_Tsl[['Open','Open:50Days','Open:200Days']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
## Expanding
## CMA
df_Tsl['Open'].expanding().mean().plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
# EWMA Epo Weighted Moving Avg.
# Focus on the new upcoming data

# %%
# Ema on tesla
# Smoothning factor - 0.1

# %%
df_Tsl['Ema_0.1']=df_Tsl['Open'].ewm(alpha=0.1,adjust=False).mean()

# %%
df_Tsl[['Open','Ema_0.1']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
df_Tsl['Ema_0.3']=df_Tsl['Open'].ewm(alpha=0.3,adjust=False).mean()

# %%
df_Tsl[['Open','Ema_0.1','Ema_0.3']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>

# %%
## Emplemetation of EWMA
df_Tsl['Ewma_05']=df_Tsl['Open'].ewm(span=9).mean()

# %%
df_Tsl[['Open','Ewma_05']].plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Date'>
